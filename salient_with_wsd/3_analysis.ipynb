# %%
# en -> zh
def print_translations():
    with open("./en-zh.en-filtered-wsd.en.subword.test.desubword", 'r', encoding='utf-8') as en_file, \
         open("./zh.translated.desubword", 'r', encoding='utf-8') as zh_bert_file, \
         open("./zh.base.translated.desubword", 'r', encoding='utf-8') as zh_base_file, \
         open("./en-zh.zh-filtered-wsd.zh.subword.test.desubword", encoding="utf-8") as zh_correct_file:
        
        for en_line, zh_bert_line, zh_base_line, zh_correct_line in zip(en_file, zh_bert_file, zh_base_file, zh_correct_file):
            en_line = en_line.strip()
            zh_bert_line = zh_bert_line.strip()
            zh_base_line = zh_base_line.strip()
            zh_correct_line = zh_correct_line.strip()
            
            print(f"English:            {en_line}")
            print(f"Chinese (bert):     {zh_bert_line}")
            print(f"Chinese (base):     {zh_base_line}")
            print(f"Chinese (correct):  {zh_correct_line}")
            print("-" * 50)

print_translations()
# Out:
# English:            Dictatorships in Czechoslovakia, East Germany, Estonia, Latvia, Lithuania, Mali, Madagascar, Poland, the Philippines, Serbia, Slovenia, I could go on, and now Tunisia and Egypt.
# Chinese (bert):     在克萨斯洛伐克,东德国, 欧沙尼亚,拉维亚,里南, 利萨维亚,马里兰, 奥地利,奥地利, 奥里兰,塞维亚,我还可以继续, 继续努力。
# Chinese (base):     在捷克洛伐克的达基地, 东德国,爱沙尼亚、拉塔维亚、马斯达加、马里斯加、马达加斯加、 宾夕法尼亚、塞尔维亚、斯洛文尼亚、 斯洛文尼亚、突尼西亚、埃及。
# Chinese (correct):  在捷克斯洛伐克,东德 爱沙尼亚,拉脱维亚,立陶宛, 马里,马达加斯加, 波兰,菲律宾, 塞尔维亚,斯洛维尼亚的独裁政府,我可以继续, 还有现在的突尼斯和埃及。
# --------------------------------------------------
# English:            I don't know what they're going to do with all that stuff.
# Chinese (bert):     我不知道他们要用这些东西做什么
# Chinese (base):     我不知道他们要怎么处理那些东西。
# Chinese (correct):  我不知道他们将怎么处理那些东西。
# --------------------------------------------------
# English:            It demands some sort of notion of inquiry because it's a system that's developed not sculpturally.
# Chinese (bert):     它需要某种交通系统来规划, 因为它是一个没有交通系统的系统。
# Chinese (base):     它要求某种看证的概念 是一个没有雕刻的系统。
# Chinese (correct):  这需要有探求精神 因为这整个系统不是以雕塑形式做成的
# --------------------------------------------------
# English:            Great teachers do that, but what great teachers also do is mentor, stimulate, provoke, engage.
# Chinese (bert):     大公司会这样做,但是 大公司也做得很好。
# Chinese (base):     伟大的教师这样做,但是伟大的教师们也是这样, 指导、激励和投入。
# Chinese (correct):  优秀的教师的确要这样做 但同时他们还会指导学生的学习 激发学生的兴趣,挑起学生的热情,赢得学生的关注
# --------------------------------------------------
# English:            And so I'm just plugging and chugging through this gargantuan task, and finally, on the 4,000th try, when I'm close to losing my sanity, I find the protein.
# Chinese (bert):     所以,我只是用这种排骨和甘地的薄板 插到最后,在4000英里的地上, 当我靠近我的神圣门时, 我发现蛋白质。
# Chinese (base):     所以我只是在方圆柱的任务上加力减速, 最终,在4000次努力中, 当我靠近我的正常线时, 我发现蛋白质。
# Chinese (correct):  我按部就班地执行艰巨的任务 终于在第4000次筛选的时候 在我快发疯的时候 找到了符合标准的蛋白质
# --------------------------------------------------
# English:            And I noticed that they would move this little thermoregulatory device to change the temperature in their home by one degree or two degrees.
# Chinese (bert):     我注意到他们会移动这个微缩设备, 用来改变家的温度, 一到两英寸。
# Chinese (base):     我注意到,它们会 通过一度或两度的温度来改变家庭的温度。
# Chinese (correct):  我还发现他们在家里安装了 小巧的调温装置, 可以一度一度地或者两度两度地调解 家里的室内温度。
# --------------------------------------------------
# English:            But this is a consequence.
# Chinese (bert):     但是这是一个谜.
# Chinese (base):     这是个后果。
# Chinese (correct):  但是这只是一种研究结论
# --------------------------------------------------
# English:            So, the average age of a person in Second Life is 32, however, the use of Second Life increases dramatically as your physical age increases. So as you go from age 30 to age 60 -- and there are many people in their sixties using Second Life -- this is also not a sharp curve -- it's very, very distributed -- usage goes up in terms of, like, hours per week by 40 percent
# Chinese (bert):     平均年龄是32岁, 正常年龄的人的平均年龄是32岁。 但是,当你们从30岁到60岁—— 60岁的人—— 60岁以上的人在使用代数自行车, 这当然不是很合常用的—— 我们每月都会增加40%,
# Chinese (base):     所以“第二人生”的平均年龄是32岁, 然而“第二人生”的使用率 变得越来越大。所以当你从30岁到60岁-- 有很多人在使用“第二人生”中使用“第二人生”-- 这不是一个很尖锐的曲线-- 它的分布情况非常显著。
# Chinese (correct):  那么,“第二人生”居民的平均年龄是32岁 然而,对“第二人生”的使用急剧增长 就像你的实际年龄的增长一样。所以,如同你从30岁长到60岁 有很多人60岁时在使用“第二人生” 这不是一个陡峭的曲线——它非常非常分散 一个从30岁长到60岁的人,从每周在线时间
# --------------------------------------------------
# English:            And so it keeps thinking out loud of its own abstraction.
# Chinese (bert):     所以它继续思考着大声的表达出来。
# Chinese (base):     所以它不停地想清楚它自己的抽象。
# Chinese (correct):  它一直努力思考自身的抽象性
# --------------------------------------------------
# English:            And what's great about this is the technology's actually allowing the phone to start to see and understand much like how the human brain does.
# Chinese (bert):     它的好处在于 它允许手机开始看到 然后了解人类大脑的运作方式
# Chinese (base):     这项技术的好处在于 科技实际上使手机 开始认识和理解 人脑如何运作
# Chinese (correct):  最好的实际上是科技 允许电话去识别并且理解图片 如同人类大脑一般
# --------------------------------------------------
# English:            With an architect's help, residents literally raised it from the ground up.
# Chinese (bert):     建筑师的职业是会员, 居民实际上把它从地上提高。
# Chinese (base):     建筑师的帮助下,将居民们从地上抬起来。
# Chinese (correct):  受一位建筑师之助, 毫不夸张的说,人们从无到有地建立了这座医院。
# --------------------------------------------------
# English:            And then the students would come into our sound studios, they would make their own rap songs with their own beats.
# Chinese (bert):     然后学生走进我们的声音办公室, 他们用自己的模型做出自己的模型。
# Chinese (base):     然后学生会加入我们的声音室, 他们会用他们自己的节奏创造他们自己的说唱诗。
# Chinese (correct):  于是这些学生会来我们的音乐工作室 他们用他们自己的节拍创作音乐
# --------------------------------------------------
# English:            Sometimes I get little old ladies from the Seventh Day Adventist Church showing me these cartoon pictures of heaven.
# Chinese (bert):     有时候我有点太老太太太太太太太太太太晚了, 留下了无神论者的图画。
# Chinese (base):     有时我从第七天的老太太太太太太太 小心 教会了我一些天堂的照片。
# Chinese (correct):  有时候基督复临安息日教会的老妇人们会来 给我看一些天堂的卡通图片。
# --------------------------------------------------
# English:            And if you fill the cup with local agriculture from small farmers, you have a transformative effect.
# Chinese (bert):     如果你填上小额信贷的一杯, 你就产生了一次革命。
# Chinese (base):     如果你用当地农业来填满 小农场主的水源, 你就有了变化的效果。
# Chinese (correct):  如果你用当地小规模农民生产的作物 那么你就已经起到了改变的作用。
# --------------------------------------------------
# English:            Then, she approaches him after an hour, he says, "Who are you?
# Chinese (bert):     然后,在飓风后,她问他, “你是谁?”
# Chinese (base):     然后,她在他一小时后到达, 他说,“你是谁?”
# Chinese (correct):  但一个小时候当母亲走到面前,他会问:“你是谁?”
# --------------------------------------------------
# English:            Now, very clearly, I'm going to gather the deck together.
# Chinese (bert):     现在,我要非常小心地把轮子组合起来。
# Chinese (base):     现在,非常明显的,我要把这些牌聚集起来。
# Chinese (correct):  好,毫无疑问,我要把牌收到一起,
# --------------------------------------------------
# English:            It's an integrated system that has evolved despite all the planning and so on.
# Chinese (bert):     它是个有功能的系统 尽管有计划等等,它也进化了。
# Chinese (base):     它是一个综合的系统,尽管有规划,等等。
# Chinese (correct):  这个综合体系 不停演进 无论如何规划都是如此
# --------------------------------------------------
# English:            Then modern humans emerged somewhere in Africa, came out of Africa, presumably in the Middle East.
# Chinese (bert):     现代人走出非洲, 走出非洲,来到中东。
# Chinese (base):     然后现代人类出现在非洲的某个地方, 很可能来自于中东。
# Chinese (correct):  现代人随后在非洲出现 走出了非洲 我们认为他们去到了中东
# --------------------------------------------------
# English:            these disruptions help us solve problems, they help us become more creative.
# Chinese (bert):     这些魔法帮助我们解决问题, 帮助我们变得更有创造力。
# Chinese (base):     这些干扰对我们解决问题, 帮助我们变得更有创造力。
# Chinese (correct):  这些阻碍使我们更好地解决问题, 它们使我们更加迸发创意。
# --------------------------------------------------
# English:            Gene is looking a little older.
# Chinese (bert):     格伦看上去有点头发。
# Chinese (base):     格伦看起来有点老了。
# Chinese (correct):  格伦看上去老了一些。
# --------------------------------------------------
# English:            Wouldn't it be awesome if you could, for the first time, get eyewear that actually fits you perfectly and doesn't require any hinge assembly, so chances are, the hinges are not going to break?
# Chinese (bert):     如果可以的话,那不是很棒吗? 第一次你会得到眼镜, 可以很完美的配合, 不需要任何螺丝钉, 所以机会是用不着洗衣机。
# Chinese (base):     如果可以的话,那不是“棒极了”吗? 第一次看到这样的眼皮内 能完全适应你, 而且不需要任何的打猎物, 所以更有可能的是,  ⁇ 虫不会摔碎吗?
# Chinese (correct):  如果你能前所未有地 戴上不是由镜框、镜架组装成的, 完美贴合脸部的眼镜, 岂不是很酷吗? 很有可能的是,镜架永远不会断裂。
# --------------------------------------------------
# English:            Now, the growth of China is part of a dramatic change, fundamental change, Just 25 years ago, the developing countries, the poorer countries of the world, were, notwithstanding being the vast majority of the people, they accounted for only about a third of the world's output.
# Chinese (bert):     现在,中国的增长是 具有革命性的变革, 在25年前, 发展中国家, 穷国的发展中国家, 并非智障, 成为世界占人口的三分之一。
# Chinese (base):     现在,中国的经济增长 是严峻的改变,基础上的改变, 25年前,发展中国家, 穷国,尽管是, 依然是大多数人的, 他们只占了世界总产量的三分之一。
# Chinese (correct):  中国的发展是世界经济格局的 重要而深远的变革之一。 就在25年前,发展中国家, 世界上这些相对较贫困的国家, 尽管拥有世界上最多的人口, 它们只占了全世界产出的三分之一,
# --------------------------------------------------
# English:            Of course, now I'm very sensitive at home when we leave the lights on by mistake.
# Chinese (bert):     当然了,现在我真的很敏感, 当我们离开家的灯。
# Chinese (base):     当然了,现在在家中我非常敏感 当我们把灯熄灭时。
# Chinese (correct):  当然了,现在我对家里不必要的开灯非常敏感。
# --------------------------------------------------
# English:            The lowest performing country, Central African Republic, scores 31.
# Chinese (bert):     毛里求斯国家中部 中央分区是31分。
# Chinese (base):     表现最小的国家,中共和国, 31分。
# Chinese (correct):  成绩最低的国家是中非共和国,31分。
# --------------------------------------------------
# English:            These are all natural human impulses, but because of technology, acting on these impulses is only one click away.
# Chinese (bert):     这些都是人类天生的奇迹, 但是因为科技,在这些声誉中, 仅仅是一个点击。
# Chinese (base):     这些都是天然的人类冲动, 但是因为技术, 执行这些冲动只是一次点击。
# Chinese (correct):  这都是人类天生的冲动, 但因为科技, 让这些冲动发酵 只要一个点击而已。
# --------------------------------------------------
# English:            Something like this is what I first saw when I jumped in the water for the first time in the Mediterranean coast off Spain.
# Chinese (bert):     这是我第一次在 加拉帕戈斯群岛的水域潜水时 第一次看见的。
# Chinese (base):     这是我第一次观察到的, 当我在西班牙海湾上第一次跳下水时。
# Chinese (correct):  当我第一次潜水的时候 首先看到的就是这些东西 那是在地中海的西班牙沿岸
# --------------------------------------------------
# English:            Now, that played itself out in the World Cup campaign.
# Chinese (bert):     现在,它自己在世贸市场里播放。
# Chinese (base):     这本身也存在于世界杯赛选中。
# Chinese (correct):  这点在世界杯宣传期间得到了充分证明。
# --------------------------------------------------
# English:            And we did indeed find it.
# Chinese (bert):     我们确实找到了
# Chinese (base):     我们确实找到了。
# Chinese (correct):  而且我们如愿所偿。
# --------------------------------------------------
# English:            People I know who are firemen told me that this is not uncommon.
# Chinese (bert):     据我所知,在消防员的人告诉我, 这不是一个愚蠢的问题。
# Chinese (base):     我知道有消防员的人告诉我 这一点也不稀奇。
# Chinese (correct):  我认识的一个消防队员告诉我这种事情经常发生.
# --------------------------------------------------
# English:            No, I think he’s talking about selective forestry.
# Chinese (bert):     不,我想巴西 谈论林业。
# Chinese (base):     不,我认为他谈的是选择性的森林。
# Chinese (correct):  不,我觉得他讲选择性林业。
# --------------------------------------------------
# English:            She came charging out of the thicket straight towards us, sat next to us, shivering, with her back towards Dereck, and looking out.
# Chinese (bert):     她从耳边走出来, 靠近我们,坐在我们旁边, 静地看着她靠近德雷克, 转过头。
# Chinese (base):     她带着那根深蒂固的车过来, 坐在我们旁边, 颤抖,带着她回到了迪勒克, 看着我。
# Chinese (correct):  她从树丛中出来,径直走向我们, 在我们旁边坐下,瑟瑟发抖。 她背对着Dereck,四处张望。
# --------------------------------------------------
# English:            I mean, it dwarfs, dwarfs everything that is actually on our news agenda, and it's invisible.
# Chinese (bert):     我的意思是,它诠释了所有的关于新闻的讨论, 并且它是假的。
# Chinese (base):     我是说,它比大巫见大巫了, 比起我们在新闻议程上真正的一切, 它是无形的。
# Chinese (correct):  这很了不起,比任何实体的新闻事件更了不起
# --------------------------------------------------
# English:            Of course we also, particularly in the last decade, managed to envelop the world in a dense chain of supermarkets, in a chain of global trade.
# Chinese (bert):     当然,我们还有特别在去年的十年, 成功地在全球超市里的货架上 解决了全球问题。
# Chinese (base):     当然,在过去的十年中, 我们成功地在全世界繁盛, 在全球贸易的链条中。
# Chinese (correct):  当然我们也,特别是在前几十年里, 让我们的世界包裹在 一个超市链里, 一个全球贸易里。
# --------------------------------------------------
# English:            And the fax said, there should be songs, there should be an "I want" song, there should be a happy village song, there should be a love story and there should be a villain.
# Chinese (bert):     歌弦说,本应有创作力, 应该有一首“我发现”的歌曲, 既要有优美的故事, 哪里就有爱故事, 哪里应该有更优美的故事。
# Chinese (base):     传真道上应该有歌曲, 应该有一首“我想要”的歌, 应该有一个开心的村庄歌曲, 应该有一个爱故事, 也有播报废。
# Chinese (correct):  上面写着 应该要有唱歌 应该要有个“我想要”的歌曲 要有个关于快乐小镇的歌曲 还得有个爱情故事 和一个反派角色
# --------------------------------------------------
# English:            So in our third year, how did we do it?
# Chinese (bert):     所以在我们的第三年 我们是怎么做到的?
# Chinese (base):     所以在我们的第三年,我们是怎么做到的?
# Chinese (correct):  到了我们办学的第三年,我们的学校是什么样子的呢?
# --------------------------------------------------
# English:            Now, I don't have a TV, which makes me a freak, but very productive -- And there's an episode of "Lost" where one guy has a lucky number, but it's not a lucky number, it's why he's on the island, but they looked and the numbers did not match.
# Chinese (bert):     现在,我没有一个数字, 这让我很沮丧, 但非常沮丧。 有一些关于"苹果"的单词, 一个人有一个“苹果”, 但这并不是一个数字, 但这数字不是质数, 但看起来和数字并没变。
# Chinese (base):     现在,我没有一台电视, 让我觉得很反常,但是却非常高效。 有一集“孤独”的一集, 一个人有一个幸运号, 但这不是一条幸运号, 这也是为什么他在岛上, 看着那些数据不匹配。
# Chinese (correct):  我没有电视机, 别人觉得我很古怪,但这使得我工作富有成效～ 我知道,这一集《迷失》 讲的是一个白人的幸运号码, 事实上却不是幸运号码, 讲的是他们在岛上呆了多长时间, 他们对照了, 号码不相符。
# --------------------------------------------------
# English:            I hope.
# Chinese (bert):     我希望,我希望
# Chinese (base):     我希望
# Chinese (correct):  希望如此。
# --------------------------------------------------
# English:            He said, "Bono, wouldn't that be a good use of your messianic complex?
# Chinese (bert):     他说:“晚安,你的儿科医生不会用你的麻醉药吗?”
# Chinese (base):     他说:“本事,那不就是好用 复杂吗?”
# Chinese (correct):  他说:“Bono,难道你不觉得这是展示你的弥赛亚情节的好机会吗?”
# --------------------------------------------------
# English:            So I did that.
# Chinese (bert):     我做到了。
# Chinese (base):     于是我就这么做了。
# Chinese (correct):  于是我就照做了。
# --------------------------------------------------
# English:            We have experiences in our lives, certainly, when sharing has been irresistible.
# Chinese (bert):     我们的生活中有很多经历, 当然,分享是被动的。
# Chinese (base):     我们生活中有很多经历, 当然,当分享是不可逆转的。
# Chinese (correct):  我们在生活中当然也体验到 分享的魅力
# --------------------------------------------------
# English:            Others make differences and changes to the physics at the sub-atomic level.
# Chinese (bert):     物理差异会改变物理 在宏观层面。
# Chinese (base):     其它人在亚原子级别上 改变了物理现象。
# Chinese (correct):  另一些人认为,暗能量的变化 存在于亚原子表面。
# --------------------------------------------------
# English:            But literally within days of arriving I was told, in no uncertain terms, by a number of West African women, that Africans didn't want saving, thank you very much, least of all not by me.
# Chinese (bert):     但是实际上,在监狱的几天里, 我被关押了,因为很多西非的 非洲女性所崇拜, 非洲人非常不愿意听我讲。
# Chinese (base):     但是,在到达的日子里, 我从来没有被别人告诉过, 西方国家的妇女们, 非洲人并不需要储蓄, 十分感谢你们, 至少我不是我。
# Chinese (correct):  但自从我到达这里,就不断有西非妇女 明确地告诉我非洲人不需要被拯救, 尤其是被我这样的人拯救,非常感谢你。
# --------------------------------------------------
# English:            This is very strange for me, because I’m not used to doing this: I usually stand on the other side of the light, and now I'm feeling the pressure I put other people into. And it's hard ...
# Chinese (bert):     这对我来说是很奇怪的,因为 我通常不常这么做: 我挺身而出,现在我感觉到 他人的压迫。这很难。
# Chinese (base):     这对我来说很奇怪, 因为我不是经常这样做的: 我常常站在光明的一边, 现在我正在感觉到 把其他人身上的压力施加进来。这很难。
# Chinese (correct):  这对于我来说怪怪的,因为我不习惯做这样的演讲 通常我都是站在镁光灯的另一边 现在我感觉到我曾经带给其他人的压力了,这可不太好受
# --------------------------------------------------
# English:            And at this point, we've come 100,000 light-years from here.
# Chinese (bert):     到现在,我们已经有10万光年了。
# Chinese (base):     至此,我们离这里10万年的光年
# Chinese (correct):  而到达此地,我们已经跨越了十万光年。
# --------------------------------------------------
# English:            This is not big news to viticulturists; they have been, you know, concerned with water and fertilization.
# Chinese (bert):     这对于鸟类特例来说并不是什么大新闻, 他们非常关心水和卫生。
# Chinese (base):     这可不是什么大新闻,你知道, 担心水和灌溉。
# Chinese (correct):  这对于葡萄栽培者来说不是大新闻 要知道他们一直注意着浇水和施肥
# --------------------------------------------------
# English:            It's like, are science and plumbing compatible?
# Chinese (bert):     就像是,科学和刺激的责任?”
# Chinese (base):     就像是,科学和空间兼容性吗?
# Chinese (correct):  像是在问科学与水电并立吗?
# --------------------------------------------------
# English:            But I look at that statistic and, if you, like me, believe that leadership manifests at every level, you would see that there's a tremendous, awesome resource of leaders who are leading in middle management, which raises a different question: Why are there so many women mired in the middle and what has to happen to take them to the top?
# Chinese (bert):     但我会看那个定义,如果你和我一样, 相信领导力学院在每个阶段都孕育着领导, 你会发现一个具有代表性的资源, 领导着一个不一样的问题: 为什么女性在中层中占有地位, 以及她们必须面对的是什么?
# Chinese (base):     但我看到这个统计数据后,如果你像我一样, 相信领导力在每个层次上都宣示, 你会看到巨大的、 极棒的资源 这些领导者在中层管理中领导, 这引发了另外一个问题: 为什么那么多女性 中层作用在中层, 要怎样让她们成为领导者?
# Chinese (correct):  但是我看着这个统计数据 并且,如果你跟我一样,相信 那上面显示的各级别领导人数, 你会看到中管管理 有着数量惊人的 杰出女性领导者, 由此你会提出另一个问题: 为什么有这么多女性 卡在中层? 她们怎样 才能升到高层?
# --------------------------------------------------
# English:            I'm not like most of the people you'll have heard speaking about prostitution before.
# Chinese (bert):     我之前所没有提到过卖淫的人。
# Chinese (base):     我和你们大多数听过卖淫的人不同。
# Chinese (correct):  我不像很多之前各位听到过的 以卖淫为主题的演讲者。
# --------------------------------------------------
# English:            We dispose of our waste properly, we follow safety procedures, we don't work with pathogens.
# Chinese (bert):     我们的垃圾邮件. 我们跟踪安全记录. 我们不是为了病原体.
# Chinese (base):     我们把废物处理的正确处理, 我们遵循安全程序, 我们不会和病原体一起工作。
# Chinese (correct):  合理处置废料垃圾 遵守安全细则,不使用病原体
# --------------------------------------------------
# English:            But I am also trying to make sanitary pad with the good cotton. It's not working.
# Chinese (bert):     但我同时尝试用益生菌来补给它们,而不是害虫。
# Chinese (base):     但我也试着用棉质来做卫生巾。 这行不通。
# Chinese (correct):  我同样用好棉花,就做不出好用的卫生巾
# --------------------------------------------------
# English:            So yes, there are people who might be interested in joining the Islamic State in the United States, and those are people that the United States government should be looking at to see if they're interested in violence here.
# Chinese (bert):     所以,是的, 某些人可能正在加入 伊斯兰国的伊斯兰国度, 而这些人就是穆斯林政府 应该关注他们是否受到暴力侵犯。
# Chinese (base):     所以是的,有些人可能对 美国伊斯兰国加入伊斯兰国 而那些是美国政府应关注 是否对暴力事件感兴趣的人。
# Chinese (correct):  的确,在美国也许会有人对加入 “伊斯兰国”感兴趣, 这部分人才是美国政府应该关注的, 看他们是不是有暴力倾向。
# --------------------------------------------------
# English:            But I'm going to show you two videos, two mothers -- one is lying, one is telling the truth.
# Chinese (bert):     但是我要向大家展示两个母亲, 一个是女病人,一个是用来讲述事实。
# Chinese (base):     但是我要给你们看两个视频, 两个女人,一个是说谎, 一个在说真话。
# Chinese (correct):  但我将播放两段视频 两位母亲 一位在说谎 一位在说实话 两段视频都是由
# --------------------------------------------------
# English:            I found it myself.
# Chinese (bert):     我找到了自己。
# Chinese (base):     我找到了。
# Chinese (correct):  我自己找到了它。
# --------------------------------------------------
# English:            NT: Everything I did, I did for mankind, for a world where there would be no humiliation of the poor by the violence of the rich, where products of intellect, science and art will serve society for the betterment and beautification of life.
# Chinese (bert):     特斯拉:“我做的一切, 为人类, 为世界而做的一切, 不会对穷人的矛盾施加阻碍, 因为生产科幻小说 和艺术将为人类带来更好的痛苦、 享受生活。
# Chinese (base):     特斯拉:“我做的每件事, 为人类而做的, 对于一个穷人来说, 没有对穷人的羞辱, 受教育, 科学和艺术, 都会为社会带来 更美好、更荣耀的生活。”
# Chinese (correct):  特斯拉:“我做的每件事都是为了全人类。” 特斯拉:“都是为了穷人们不再被富人欺负,” 特斯拉:“为了智慧,科学与艺术的产物” 特斯拉:“能过造福社会,美化我们的生活。”
# --------------------------------------------------
# English:            It's going to require a lot of work, a lot of research.
# Chinese (bert):     这需要很多工作,很多研究。
# Chinese (base):     这项研究需要很多的工作和研究。
# Chinese (correct):  这将需要我们不断的努力, 很多很多的科研。
# --------------------------------------------------
# English:            And very often, as you know, new ideas are often simple connections between people with different experiences in different communities, and that's our story.
# Chinese (bert):     如你所知,新思想是 在不同情况下有不同经验的人之间的简单连接, 这就是我们的故事。
# Chinese (base):     而且,经常,正如你所知, 新想法常常是人们 与不同社区不同的经历之间的联系, 这是我们的故事。
# Chinese (correct):  大家知道,新颖的想法往往只是一些 不同机构里跨领域跨背景的人 相互沟通后的产物, 而这就是我们的故事。
# --------------------------------------------------
# English:            I don’t remember how we got there.
# Chinese (bert):     我还记得我们是怎么到达那里的。
# Chinese (base):     我不记得我们是怎么走到那里的。
# Chinese (correct):  我记不得我们是怎么去到那里的
# --------------------------------------------------
# English:            I like it as a component of global change to talk about, because, even if you are a hard-bitten global warming skeptic, and I talk to that community fairly often, you cannot deny of CO2 dissolving in the ocean.
# Chinese (bert):     我喜欢它是一个全球暖化气候变化的倡导, 因为,即使你是个 坚硬的全球温室效应的全球温室效应, 我也经常和社区说, 你也不可能在海洋里排放二氧化碳。
# Chinese (base):     我喜欢它是全球变化的一个组团, 因为,即使你是一个难以接受的全球暖化问题, 我会更加质疑这个社区, 也不能在海中拒绝二氧化碳。
# Chinese (correct):  我希望将它作为全球变化的一个组成部分来讨论, 因为,即使你是一个固执的全球变暖怀疑论者, 你也不能否认 二氧化碳正在被海洋 吸收这个简单的事实。
# --------------------------------------------------
# English:            I'm going to share two directions that are new in my work.
# Chinese (bert):     我接下来要分享两个我所从事的领域。
# Chinese (base):     我要分享我工作中两个新方向。
# Chinese (correct):  我想要与大家分享我工作中 两个新的方向
# --------------------------------------------------
# English:            Why don't we feel compassion for rocks?
# Chinese (bert):     为什么我们不同情受害者?
# Chinese (base):     为什么我们不同情石头?
# Chinese (correct):  为什么我们对石头没有仁爱之情?
# --------------------------------------------------
# English:            This is showing making bits, this is showing -- once again, slowed down so you can see it, bits interacting to do logic and multiplexing and de-multiplexing.
# Chinese (bert):     这是动态制作的,这是动态—— 再一次,放慢速度,这样你可以看见, 互动和互动, 互动和放慢节奏。
# Chinese (base):     这展示的是小东西,这里展示的是-- 再一次,减慢了速度,所以你可以看到, 点触动了逻辑, 多x,以及多x摆弄。
# Chinese (correct):  这是生产比特的过程,这是一个展示 大家看看这个慢镜头 比特相互作用产生逻辑,而后扩散又汇聚
# --------------------------------------------------
# English:            Then the developing countries applied soap and water, vaccination.
# Chinese (bert):     之后,发展中国家 使用了盐水和灌溉。
# Chinese (base):     然后发展中国家使用肥皂和水, 接种疫苗。
# Chinese (correct):  发展中国家应用了 肥皂和水,疫苗。
# --------------------------------------------------
# English:            We have a split wing.
# Chinese (bert):     我们有一个分解的过程。
# Chinese (base):     我们有一个分开的翅膀。
# Chinese (correct):  我们采用了分裂式翼。
# --------------------------------------------------
# English:            They are doing that on a quarter of the resources that are used typically in [the] Western world -- a quarter of the resources.
# Chinese (bert):     是在西方世界普遍普遍普遍认为的一种商品-- 一种商品的价格。
# Chinese (base):     他们只用了 25 % 的资源, 在西方世界 —— 四分之一的资源。
# Chinese (correct):  但是他们只使用了 典型的西方世界所用资源的 四分之一, 只用四分之一的资源。
# --------------------------------------------------
# English:            We're moving to what I would think of as a fully connected system, and we have global decisions to make in this system, decisions about climate, about finance systems, about resources. And think about it -- if we want to make an important decision about buying a house, we don't just go off. I mean, I don't know about you, but I want to see a lot of houses before I put that much money into it.
# Chinese (bert):     我们将要步入一个完全连接的系统, 我们有全球性工具来建立这个体系, 应用和维持系统。想想它——如果我们想做 一个重要的决定, 我们不要仅仅取消一个房子。我的意思是,我并不了解你, 我想先看看这个体系。
# Chinese (base):     我们正在迈向一个完全连接的系统, 我们有着全球性的决策, 应对气候,金融体系, 以及资源。想想, 如果我们想做一个重要决定, 购买房子, 我们不会离开。我的意思是,我不知道你, 但在我不想看到很多房子。
# Chinese (correct):  我认为,我们已经进入完全连接的世界 我们可以在这个世界做出全球化的决定 做出关于气候,金融系统,以及资源分配的决定 想想吧 如果我们做买房子这样重要的决定 我们不是立即就做决定。虽然我不知道你们会不会, 但在投入大量资金之前我还想多看些房子
# --------------------------------------------------
# English:            Those are captured in the charter.
# Chinese (bert):     它们在捕食者的手中。
# Chinese (base):     这是在图表中被捕捉的。
# Chinese (correct):  这些将在纲领中体现出来
# --------------------------------------------------
# English:            I'm in thongs and sarongs. It was many years ago.
# Chinese (bert):     我在蛇和蛇 也就是很多年前。
# Chinese (base):     我是海绵和海绵,很多年前。
# Chinese (correct):  我穿着人字拖和莎笼裙 而且是很多年前
# --------------------------------------------------
# English:            And experience is not just a kind of entertainment in a non-casual way.
# Chinese (bert):     体验不是一个合乎逻辑的娱乐,
# Chinese (base):     体验不仅仅是一种非传统的方式娱乐。
# Chinese (correct):  经验不仅是 一种不计因果的娱乐。
# --------------------------------------------------
# English:            So just like personalized medicine, while you might imagine wanting to treat every patient individually, what we'd like to do is build models of individual plants and then tell the farmer what kind of inputs every plant needs -- the inputs in this case being water, fertilizer and pesticide.
# Chinese (bert):     就像是花椰菜一般,你或许会想 对待每个病人,我们想做的是 建立个人植物的模样 然后告诉农民 每种植物都需要什么燃料-- 这种情况下是肥料和杀虫剂。
# Chinese (base):     就像个性化的医疗一样, 尽管你想象着要对每个患者 进行个性化治疗, 我们希望要去建立 单个植物的模型, 然后告诉农民 每种植物需求什么输入, 这次的投入是水,化和杀虫剂。
# Chinese (correct):  就像个性化的机器, 想象每个病人都有一对一服务, 我们要做的就是 为每株植物单独建立模型, 然后告诉农民 每株植物各需要些什么—— 需要的因素在这里指的是水, 肥料和杀虫剂。
# --------------------------------------------------
# English:            And they would say, "Well, what about you?
# Chinese (bert):     他们说:“那么,你呢?”
# Chinese (base):     他们说:“那你呢?”
# Chinese (correct):  他们会 说:"噢,那你不是吗?
# --------------------------------------------------
# English:            But it's not really what is probably most efficient.
# Chinese (bert):     但这并不是最让人惊讶的情形
# Chinese (base):     但这并不是最有效的。
# Chinese (correct):  但同时这也说明他所作的并不是最有效的。
# --------------------------------------------------
# English:            How is it that we can actually take this type of activity elsewhere?
# Chinese (bert):     我们如何真正在其他地方利用这样的活动?
# Chinese (base):     我们如何才能将这些活动带到其他的地方?
# Chinese (correct):  我们怎样才能 在别的地方也做这些工作呢?
# --------------------------------------------------
# English:            He's a young, Cameroonian design engineer who has a adapted a tablet computer into the Cardiopad, a mobile heart-monitoring device.
# Chinese (bert):     他是亚利桑那的设计工程师, 他把一个桌子上的电脑 改装到车达, 一个移动的心脏。
# Chinese (base):     他是个年轻、喀麦隆设计工程师, 他将一台平板电脑 改编成卡迪奥, 一台手机模拟器。
# Chinese (correct):  一个喀麦隆年轻的设计工程师, 他把平板电脑变成了Cardiopad, 一种移动心脏监测设备。
# --------------------------------------------------
# English:            This book became, naturally, an enormous best-seller.
# Chinese (bert):     这本书引起了巨大的质疑
# Chinese (base):     这本书在自然中成为一流的畅销书。
# Chinese (correct):  这本书成为史上最牛的畅销书籍.
# --------------------------------------------------
# English:            But look at how predictable this is.
# Chinese (bert):     但是看看这是怎样预测的
# Chinese (base):     但是看看这是如何预测的。
# Chinese (correct):  看看科技发展是多么好预测的。
# --------------------------------------------------
# English:            It's rooted in a principle of retributive justice, or an eye for an eye, so retaliatory killings have led to several deaths in the area.
# Chinese (bert):     它采用了一种复活节岛上的原则, 或者对眼睛的一种态度, 因此 ⁇ 捕杀虫剂 导致地区数以百万计的死亡。
# Chinese (base):     本质上,它根植于复苏正义的原则上, 或者一只眼睛的眼神, 因此,报复的残杀 导致这个地区死亡。
# Chinese (correct):  报复性正义原则, 或者说“以牙还牙,以眼还眼”的原则在这里根深蒂固, 所以报复性杀人 造成这一地区多人死亡。
# --------------------------------------------------
# English:            Clearly, it didn't come out of a Tonight Show monologue.
# Chinese (bert):     忽然间,它没有从开普勒计划出来。
# Chinese (base):     很显然,这并非来自Tounter Towlu的独白.
# Chinese (correct):  明显的,它不是出自“今夜秀”的独白
# --------------------------------------------------
# English:            Because when we think about blogs, I think for most of us who are concerned about them, we're primarily concerned with things like politics, technology, etc.
# Chinese (bert):     因为当我们想到政客的时候, 我想对于大多数对此感兴趣的人, 我们会对政治、技术、等等感到乐观。
# Chinese (base):     因为,当我们想到博客, 我想对于大多数关注他们的人, 我们主要关心政治,科技等等。
# Chinese (correct):  我们在思考博客的时候, 我想对于大多数关心他们的人, 我们主要关注的是政治,科技以及其他,
# --------------------------------------------------
# English:            So we took ER-1 to the evaluation room.
# Chinese (bert):     所以我们把1-1带到急诊室。
# Chinese (base):     于是我们把ER1带到了评价室
# Chinese (correct):  于是我们把ER1带到评估室。
# --------------------------------------------------
# English:            And I have to understand that my needs sometimes have to be sublimated to other needs.
# Chinese (bert):     我必须明白, 我的使命 有时需要被其他的需要。
# Chinese (base):     我必须明白,我有时需要 代替其他需要。
# Chinese (correct):  我必须了解我个人的需求 有时候要升华成其他更重要的需求
# --------------------------------------------------
# English:            This book I wrote because I want to figure out life.
# Chinese (bert):     我写的这本书是因为我想搞清楚生命。
# Chinese (base):     我写的这本书是想弄清楚生命。
# Chinese (correct):  我写这本书是因为我想搞明白生活是什么。
# --------------------------------------------------
# English:            Who here has had surgery?
# Chinese (bert):     这里谁曾喝过咖啡?
# Chinese (base):     在座的各位有谁有手术?
# Chinese (correct):  在座的有人接受过外科手术吗?
# --------------------------------------------------
# English:            With the advent of the Industrial Revolution with modernization of agriculture in the last few decades, since the 1960s, food availability, per head, in this world, has increased by 25 percent.
# Chinese (bert):     在农业发展的前提下, 在20世纪60年代,农业的发展和农业的发展 增长了25%。
# Chinese (base):     工业革命前发生着 农业现代化的时代 在过去的几十年里, 自从1960年代, 粮食供应,人均头部, 增长了25%。
# Chinese (correct):  在工业革命的开端, 在农业的现代化 在过去几十年里,自从1960年来, 食品供应,每人,在这个世界里 已经上升了25%。
# --------------------------------------------------
# English:            And what you're seeing here is, again, one of the most state-of-the-art textile mills.
# Chinese (bert):     你现在看到的是, 是最先进的视网膜结构之一。
# Chinese (base):     你们现在看到的是, 这是最先进的纺织车间之一。
# Chinese (correct):  大家在照片中看到的纺织厂 代表了当前纺织厂的最高水准
# --------------------------------------------------
# English:            There have been three ways to try to impact the brain: the therapist's couch, pills and the knife.
# Chinese (bert):     有过三种方法去影响社会, 心理治疗专家的走势, 和作家。
# Chinese (base):     有三种方法去影响大脑: 心理医生沙发、药丸和刀。
# Chinese (correct):  有三种可以影响脑部的方法: 透过心理治疗师的治疗、药物和手术刀。
# --------------------------------------------------
# English:            I think, at the end of these four days, that you'll come to conclude that the arc of history is a positive one, and it's towards openness.
# Chinese (bert):     我想,在这四天结束的时候, 你会得出结论, 历史的趋势是正面的, 它正在走向灾难。
# Chinese (base):     我认为,在这四天的最后, 你会断定 历史的弧线 是积极的, 而且是朝开拓的。
# Chinese (correct):  我认为,在4天之后 你们就能得出结论历史之方向 是积极的,是朝着开放发展的。
# --------------------------------------------------
# English:            But what politicians need is a range of options.
# Chinese (bert):     但是政治家需要的是一系列的策略。
# Chinese (base):     但是政治家需要的是一个一系列选择。
# Chinese (correct):  但是政客们需要的是一组选择
# --------------------------------------------------
# English:            So for every digital renegade that is revolting in the streets of Tehran, there may as well be two digital captives who are actually rebelling only in the World of Warcraft.
# Chinese (bert):     所以在巴格达的每一个新概念 都在巴尔的大街小巷上演 可以想象有两座英雄 他们确实只在魔兽世界打架
# Chinese (base):     所以对每个在德黑兰大街上的 数字海藻 都说不起来, 可能还有两个数字盖头 在魔兽世界里 反叛道者。
# Chinese (correct):  每个德黑兰街头造反的数码变节者的背后 都隐藏着 两个只在魔兽世界里反抗的数码俘虏。
# --------------------------------------------------
# English:            Andre told me, after seeing these buildings fail again and again in the same way, that there is no new research here.
# Chinese (bert):     幸运的是,当我看到这些建筑失败了, 同样地重申一遍, 这里并没有什么新的研究。
# Chinese (base):     告诉我,看到这些建筑 一遍又一遍地失败了, 这里没有新的研究。
# Chinese (correct):  安德烈告诉我, 在看到这些建筑 不断的以同种方式倒下后, 这儿没什么新的发现了。
# --------------------------------------------------
# English:            And finally, we need to really reward politicians.
# Chinese (bert):     最后,我们需要真正奖励技巧。
# Chinese (base):     最后,我们需要真正奖励政客。
# Chinese (correct):  最后,我们需要好好奖励政治家
# --------------------------------------------------
# English:            There are many people who think that the animal world is hard-wired and that there's something very, very special about man.
# Chinese (bert):     很多人认为动物世界是坚硬的, 觉得人类有些特别。
# Chinese (base):     有很多人认为 动物的世界是顽固的, 且对于人类来说是非常特殊的。
# Chinese (correct):  很多人认为动物的世界是由基因决定的, 而我们人类是非常特别的。
# --------------------------------------------------
# English:            And if you go through the first 25 or 30 names of each of the commodities, what you begin to see is, gosh, there's Cargill here, there's Cargill there, there's Cargill everywhere.
# Chinese (bert):     如果你从头25到30个名字出发, 你现在会看到, 加沙,卡吉尔在这里,还有卡吉尔, 全世界都还有嘉吉。
# Chinese (base):     如果你经历了25到30种商品的 前25-30个名字, 你开始看到的是, 凯吉尔,那边是卡吉尔, 到处都是。
# Chinese (correct):  然后当你看到经营每种商品的公司 最开头的25到30个名字, 你开始发现了 天哪,这里有嘉吉,那里也有嘉吉, 到处都是嘉吉。
# --------------------------------------------------
# English:            Now go ahead and cut.
# Chinese (bert):     继续前进。
# Chinese (base):     现在开始并切割。
# Chinese (correct):  现在把线切断
# --------------------------------------------------
# English:            If you had based your prediction, your forecast on 1900 to 1929 you'd have predicted something like this.
# Chinese (bert):     如果你的鼻子基于1900到1929年 你一定会有这样的感觉
# Chinese (base):     如果你根据你的预测 1900年到1929年 预测了这样的结果
# Chinese (correct):  如果你的预测是根据 1900年至1929年的平均增长速度 你预测的结果大概是这样.
# --------------------------------------------------
# English:            This is 26th, that's 27th.
# Chinese (bert):     这是26号,是27号。
# Chinese (base):     这是26号,是27号。
# Chinese (correct):  这条是26街,那条是27街。”
# --------------------------------------------------
# English:            That's the problem here, and she's fighting me for that, and so then I asked her a question -- I didn't know how I was going to get out of it -- I asked her a question about her days as a playwright, and again, characteristically, instead of saying, "Oh yes, I was a playwright, and this is what blah blah blah," she said, "Oh, playwright. Everybody knows I was a playwright.
# Chinese (bert):     这就是问题所在, 然后她一直在跟我争斗, 然后,我向她解释 -- 我不知我该怎样离开 -- 我给她问了个问题 -- 我把自己当成一个游戏作画家的问题, 反之说,"是的,我是一个玩耍者," 她是怎么说的," 等等。每个人都知道,
# Chinese (base):     这就是问题所在, 她跟我来打斗, 然后我问了她一个问题-- 我不知道我怎么弄懂了-- 我问了她这个问题-- 我问了她当时是剧作家, 再次强调,她不是说,“是的,我是剧作家, 诸如此类的。” 她说,“每个人都是的,大家都明白,
# Chinese (correct):  这就是问题所在,她在跟我竞争。 所以当我问她一个问题, 我不知道将得到什么样的回答。 我问她关于剧作家的生活, 这就是她的典型回答: 她不是说:“嗯,我曾经是一名剧作家,如此这般,” 而是说:“噢,剧作家啊。人人都知道我曾是个剧作家啊。
# --------------------------------------------------
# English:            It was called the Soggy Lettuce Report.
# Chinese (bert):     它叫做“教皇家学会”。
# Chinese (base):     它叫做“黑手党”。
# Chinese (correct):  这被称作“软生菜报告”。
# --------------------------------------------------
# English:            So I told you before that when we were doing it the old-fashioned way, I realized all of our work was really adding up to just a drop in the bucket -- 10, 20, 30 different programs.
# Chinese (bert):     所以在那之前,我告诉你 当我们用老方法做事时, 我意识到我们所有的工作 都只是在垃圾堆里一滴-- 10,20,30个不同的社区。
# Chinese (base):     所以在我做旧的套管制时,我告诉你, 我们所有的工作实际上只是在水桶里一小块而已。 10,20,30个不同的程序。
# Chinese (correct):  所以我之前告诉过你 当我们用老式方法做这些的时候,我意识到 所有这些工作加起来也不过是滴水之于长河 10个,20个,30个不同的程序。
# --------------------------------------------------
# English:            I have a suspicion that if we did this, we'd find that algorithms like searching, like retrieval, all of these things, are much simpler and also more effective, because they don't process the data structure of speech.
# Chinese (bert):     我有一个建议,如果我们这样做, 我们发现算法, 象对称、所有这些因素, 都更加复杂, 而且更加复杂, 因为它们并不处理海味的数据。
# Chinese (base):     我怀疑如果我们这样做了, 我们会发现像搜寻这样的算法, 像这样查询, 所有这些事情, 都更加简单和有效, 因为他们没有处理 语言的结构。
# Chinese (correct):  我有一个猜想就是如果我们做到了这个, 我们就会发现类似于搜索, 类似于检索,所有这样的算法, 简单得多同时也有效得多了, 因为他们不是处理语言的信息结构,
# --------------------------------------------------
# English:            Before we do that, I want to kind of put biology in its place.
# Chinese (bert):     在我们做这个之前, 我想把生物学放在它的位置。
# Chinese (base):     在我们这样做之前,我想把生物学放在它的位置。
# Chinese (correct):  所以在我们开始之前, 我想要摆正一下生物学的位置。
# --------------------------------------------------
# English:            Cyrus sets up a model of how you run a great multinational, multifaith, multicultural society.
# Chinese (bert):     建立一个模型, 是关于如何运作伟大的文明,多文化,多元文化。
# Chinese (base):     赛鲁士建立了一个模型, 用来管理一个伟大的跨国公司, 多民族社会。
# Chinese (correct):  他建立了一个模式 即如何治理一个庞大的 多民族,多信仰和多文化的社会
# --------------------------------------------------
# English:            They come in different shapes; they're made out of different molecules.
# Chinese (bert):     它们由不同的材料组成, 它们由不同的材料组成。
# Chinese (base):     它们来自不同的形状,它们是由不同的分子组成。
# Chinese (correct):  它们分化成不同的形状;它们分泌出不同分子;
# --------------------------------------------------
# English:            And we got lots of applicants.
# Chinese (bert):     我们有很多的物件
# Chinese (base):     我们得到了很多的应用。
# Chinese (correct):  申请者也不计其数。
# --------------------------------------------------
# English:            And a lot of what goes on inside -- There's a fish with glowing eyes, pulsating eyes.
# Chinese (bert):     在里面还有很多东西--有鱼眼睛会发光。
# Chinese (base):     内部有很多东西, 里面有一条鱼, 发光的眼睛, 脉搏。
# Chinese (correct):  再来看看这里发生了些什么—— 这条鱼有着会发光,闪烁的眼睛。
# --------------------------------------------------
# English:            And, you know, built the society that we now live in.
# Chinese (bert):     建立一种我们共同生活的社会
# Chinese (base):     建设我们生活的社会
# Chinese (correct):  并且创造出了我们今天生活的这个世界
# --------------------------------------------------
# English:            It might be things like, don't eat that day, or give them a little chemotherapy, maybe a little radiation.
# Chinese (bert):     可能是类似的事情:千万别吃那一天, 或者稍微多一点,稍微多一点。
# Chinese (base):     有可能是, 别在那一天吃东西, 或者给他们一点化疗, 可能还有一点辐射。
# Chinese (correct):  好比是,这天先别吃东西, 或者给一点点化疗, 一点点放射性治疗,
# --------------------------------------------------
# English:            Most people died around the age of 50.
# Chinese (bert):     大部分人死于30岁
# Chinese (base):     大多数人在50岁的时候去世了。
# Chinese (correct):  大多数人在 50 岁左右就过世了。
# --------------------------------------------------
# English:            They wanted us to be analytical.
# Chinese (bert):     他们希望我们结婚。
# Chinese (base):     他们希望我们能分析分析问题。
# Chinese (correct):  教我们养成分析的习惯。
# --------------------------------------------------
# English:            And it's so simple.
# Chinese (bert):     这很简单。
# Chinese (base):     非常简单
# Chinese (correct):  而且它非常的简单。
# --------------------------------------------------
# English:            I made that image of Durga and her every attribute, her every nuance, my very own.
# Chinese (bert):     我为千千万万的女王制作了这张 每一个海报,每个海报,都是我自己的
# Chinese (base):     我拍下了杜尔迦 和她的每一个特征, 她的每一个细节,每一个细节, 都包括我自身。
# Chinese (correct):  我做成了杜尔迦女神的意象 和她所有的属性和特质 我专属的意象
# --------------------------------------------------
# English:            We sent it over to Uganda.
# Chinese (bert):     我们把它送到乌干达。
# Chinese (base):     我们把它送到乌干达
# Chinese (correct):  我们就发给乌干达
# --------------------------------------------------
# English:            No offense to them. I'm glad that you all enjoy them, but at my age, just putting on the regular ones I have already gives me too much information.
# Chinese (bert):     不受它们吸引。我很高兴你们所有人都喜欢, 但就在我这个年纪, 我却一直呈现出 那些我有太多的信息。
# Chinese (base):     绝对没有冒犯之意。我很高兴你们大家都喜欢, 但在我的年代, 就如往常一样, 我已提供过很多信息。
# Chinese (correct):  我并不反感他们, 我很高兴你们都喜欢, 但在我的年纪, 只是带上我的普通的那种 已经给了我太多的信息。
# --------------------------------------------------
# English:            So basically what I didn't tell you is that about 500 million years ago, organisms starter making materials, but it took them about 50 million years to get good at it.
# Chinese (bert):     所以基本上我没有告诉你们的是 大约5亿年前, 有机体开始产生种子, 但是需要花费约5亿年才能得到更好的营养。
# Chinese (base):     所以基本上我没有告诉你们的, 大概在5亿年前, 有机体开始制造材料, 但是需要5亿年来完善它。
# Chinese (correct):  所以基本上我没有告诉各位的是 大约五亿年前,生物就开始制造材料, 大概花了五千万年变得擅长于此。
# --------------------------------------------------
# English:            Cheers.
# Chinese (bert):     录音.
# Chinese (base):     厨师
# Chinese (correct):  欢呼!
# --------------------------------------------------
# English:            IW: So we decided to do something about it.
# Chinese (bert):     IW:所以我们决定做些事情。
# Chinese (base):     IW:所以我们决定做点什么。
# Chinese (correct):  IW:所以,我们决定要做些事情。
# --------------------------------------------------
# English:            There is a teenage girl who just recently went out and knew that she needed 56 stars tattooed on the right side of her face.
# Chinese (bert):     有个小女孩最近刚刚出去 并且知道她需要56颗星星 在她脸上露出56颗星星。
# Chinese (base):     一个十几岁的女孩 刚刚出柜,知道 她需要56颗星星刺身放在自己脸上的右边。
# Chinese (correct):  还有,最近一个 少女 她要在自己的右脸 做56颗星星状的文身
# --------------------------------------------------
# English:            Consider for a moment this quote by Leduc, a hundred years ago, considering a kind of synthetic biology: "The synthesis of life, should it ever occur, will not be the sensational discovery which we usually associate with the idea.
# Chinese (bert):     想像一下, 一百年前的拉里·里奇所说的: 思考生命起源, “生命起源”, 它是否应该成为 我们通常不理解的概念。
# Chinese (base):     想想100年前,Ledu 的这段话, 想想一种合成生物: “合成生命的综合体”, 不应该出现, 不会是那种 我们通常会把它和概念联系起来的 感觉性发现。
# Chinese (correct):  试想一下 勒杜克在一百年前说的话 是关于合成生物学的 “合成生命一旦出现 将不会像我们以为的那样 耸人听闻”
# --------------------------------------------------
# English:            The post-colonial entropy that is happening around the world is accelerating, and I expect more such changes to occur in the map as the states fragment.
# Chinese (bert):     全球正在进行的冲突后的 难以想象的巨大变化, 我期待更多 出现在地图中的新陈代谢中。
# Chinese (base):     世界范围内的殖民主义 正在加速进行, 我预料更多地在地图上产生变化 作为国家碎片。
# Chinese (correct):  后殖民时期国家解体 在全球发生并在加速。 我预期地图上如此的改变会 随着这些国家的分解而越来越多。
# --------------------------------------------------
# English:            Steam engines are dangerous, and they had tremendous impact on the world, as you know -- industrial revolution and ships and locomotives.
# Chinese (bert):     蒸汽机具有高度的性质, 它们对世界有着巨大的影响, 如你所知,工业革命,船业,船业 和运动。
# Chinese (base):     稳定的引擎是危险的, 它们对世界有着巨大的影响—— 工业革命,船,还有游客。
# Chinese (correct):  蒸汽机是危险地, 众所周知,蒸汽机对世界产生了巨大影响-- 工业革命,船只,汽车。
# --------------------------------------------------
# English:            And please bear with me: I'll draw a circle and come back to this point.
# Chinese (bert):     请记住: 我画一个圈然后回到现在。
# Chinese (base):     请相信我,我来做个循环,然后再回到这一点。
# Chinese (correct):  请多包涵。 我会画一个圆圈,再回到这一问题。
# --------------------------------------------------
# English:            There will always be another frontier.
# Chinese (bert):     总会有另外一种存在。
# Chinese (base):     总会有别的前沿。
# Chinese (correct):  总会有另一片新疆土。
# --------------------------------------------------
# English:            How much money can I save?
# Chinese (bert):     我能拿多少钱?
# Chinese (base):     我能节省多少资金?
# Chinese (correct):  我能存多少钱?
# --------------------------------------------------
# English:            Ideas that didn't come out while you stare at the data will start to come out.
# Chinese (bert):     当你分析数据时,这些数据是不会外来的。
# Chinese (base):     扫描数据出的创意不会出现在你眼前。
# Chinese (correct):  盯着屏幕看数据, 绝对不会产生这样的想法。
# --------------------------------------------------
# English:            I'm assuming many of you have seen a similar chart as well, in your own corporations, or others.
# Chinese (bert):     我是名人, 你们中的许多人已经看过 类似的图表, 包括你自己的画作。
# Chinese (base):     我想你们很多人都也看过过类似的表格 关于你们自己的公司,或者别的公司。
# Chinese (correct):  我相信在座很多听众也见过类似的, 在你们的公司或其他机构中。
# --------------------------------------------------
# English:            So our dream is to bring teenagers together, so they'll have a community service experience as well as a cross-cultural experience, as they teach kids in these areas and help them build their communication infrastructure.
# Chinese (bert):     我们的梦想是将青少年们召集在一起, 这样他们就会有一个社区服务经验, 以及跨学科的经历, 在这些地区教孩子, 帮助他们建立自己的通讯网。
# Chinese (base):     我们的梦想是把青少年集合起来, 这样他们就会有一个社区服务经验, 和跨文化经历一样, 在这些地方教给孩子们沟通的 培训基础设施。
# Chinese (correct):  因此我们的梦想便是将这些青少年连接在一起, 让他们有社会服务的经历, 也让他们体验跨文化的冲击, 因为这些孩子会教当地的同龄人, 并帮他们掌握与人交流的基本能力。
# --------------------------------------------------
# English:            And these changes made the gene not act as well as the normal gene would have acted.
# Chinese (bert):     这些改变让基因不完美 和一般的遗传基因 也能改变
# Chinese (base):     这些改变使得基因的行为 不像普通基因那样运作。
# Chinese (correct):  这些变异让基因行为与正常基因相比 效果更弱一些
# --------------------------------------------------
# English:            And it's one of the yellow set of blobs around the big yellow blob.
# Chinese (bert):     这是大街上 一大群潜水器之一
# Chinese (base):     它是黄色的圈附近环绕着黄色的圆圈。
# Chinese (correct):  科学预算就是那个大黄圈圈 旁边的一个小圈圈。
# --------------------------------------------------
# English:            A slightly later migration up into the Middle East.
# Chinese (bert):     略微上升到中观世界中。
# Chinese (base):     稍后移民到了中东。
# Chinese (correct):  稍晚一点,另一部分人迁移到了中东,
# --------------------------------------------------
# English:            We all die. We all get old. We all get sick. People leave us.
# Chinese (bert):     我们都会变得老头。我们都变老了。大家都离开我们。
# Chinese (base):     我们都会死,我们都老了。 我们都得病了。大家都会病了。
# Chinese (correct):  我们都会死。我们都会变老。我们都会生病。身边的人会离开我们
# --------------------------------------------------
# English:            And so, this case report happened three weeks ago.
# Chinese (bert):     因此,这份文件在三周前发生了。
# Chinese (base):     因此,这个案子在三周前发生过。
# Chinese (correct):  这是三周前的一个病例。
# --------------------------------------------------
# English:            So just like the breast cancer story, doing research, getting awareness going, it works, you just have to get it going.
# Chinese (bert):     就像乳腺癌的故事一样, 做调研, 意识到正在发生, 你只需要点行动。
# Chinese (base):     就像乳腺癌的故事, 做研究,意识到, 这很有用,你只需要找到它。
# Chinese (correct):  就像乳腺癌的故事, 做些调查,让更多人认识到, 它管用的,我们必须继续做下去。
# --------------------------------------------------
# English:            It's not true. How could it be?
# Chinese (bert):     这不是真的。怎么会呢?
# Chinese (base):     这不是真的。怎么能做到呢?
# Chinese (correct):  这个观念是不对的。怎么可能是对的呢?
# --------------------------------------------------
# English:            They had good salaries, but theirs is still an isolating and difficult life in a dangerous and often difficult element.
# Chinese (bert):     他们有很好的工资, 但他们的收入依旧是 贬低生命 往往拥有危险的生活。
# Chinese (base):     他们有很好的芭比娃娃, 但他们的整个人生 仍是充满危险和艰难的元素。
# Chinese (correct):  他们的工资待遇不错, 但是他们过得仍然是一种孤立的、艰难的生活, 在一个危险的、困难不断的环境里面。
# --------------------------------------------------
# English:            It does not have to be nasty, scary or painful.
# Chinese (bert):     它不一定非要害怕或被冷漠。
# Chinese (base):     这不必是肮脏,可怕的或是痛苦。
# Chinese (correct):  惩罚不一定是暴力的,令人害怕的或者痛苦的。
# --------------------------------------------------
# English:            Well if we want to think about a way of getting a taste of that kind of baby consciousness as adults, I think the best thing is think about cases where we're put in a new situation that we've never been in before -- when we fall in love with someone new, or when we're in a new city for the first time.
# Chinese (bert):     如果我们想以某种方式 品尝尝这种小宝宝的意识, 我觉得最好的事情是 处于危机发生之前的情景—— 当我们坠入爱人与人之间的冲突, 或当我们第一次的城市时。
# Chinese (base):     如果我们想一种方式 达到某个层次的意识, 就像成年人一样,我觉得最好的事情是 考虑一个新陈旧的模式, 一个我们从来没有去过的地方-- 当我们坠入爱河的时候, 当我们爱上某人的时候, 或者在第一个新城市的时候。
# Chinese (correct):  见过的知觉。 如果我们大人 也想体验一下小孩的那种知觉, 我认为我们可以想象一下 给自己一个从未遇到过的状况—— 比如说当我们有了新的恋人, 或是来到一个新城市。
# --------------------------------------------------
# English:            In 2002 I met this incredible entrepreneur named Amitabha Sadangi from India, who'd been working for 20 years with some of the poorest farmers on the planet.
# Chinese (bert):     2002年,我遇到了一个不可思议的创业者, 名叫Ambada Sadhani 与来自印度的一些最贫穷的邻居合作了20年。
# Chinese (base):     在2002年,我遇到了一位了不起的企业家, 一位来自印度的 Amita Sadgani, 他与世界上最贫穷的农民一起工作20年。
# Chinese (correct):  在2002年,我与一位来自印度的 神奇的企业家艾米挞巴·萨丹吉会面, 他已经有20年与世界上最贫穷的一群农民们的经验。
# --------------------------------------------------
# English:            And collectively, those voices become our human repertoire for dealing with the challenges that will confront us in the ensuing millennia.
# Chinese (bert):     总的来说,这些声音成为了人类 面对挑战时 所面对的挑战。
# Chinese (base):     在一起,这些声音 成为了我们人类解决 即将面临的挑战 千年之久。
# Chinese (correct):  最终,这些声音成为人类 解决我们所面临的挑战的所有方法 在接下来的千年中。
# --------------------------------------------------
# English:            Maybe we can do some things.
# Chinese (bert):     也许我们可以做些事情
# Chinese (base):     也许我们可以做些事情。
# Chinese (correct):  也许我们可以做些什么。
# --------------------------------------------------
# English:            This is the Beddington Zero Energy Development in London, which is one of the greenest buildings in the world. It's a fabulous place.
# Chinese (bert):     这是Blackston I'R's 街的Beston节馆, 它是世界上最绿色的建筑之一。它是一个阴沉的地方。
# Chinese (base):     这是伦敦的伯蒂斯能源发展计划, 这是世界上最绿色建筑之一。是个不错的地方。
# Chinese (correct):  这是伦敦贝丁顿零能耗发展中心 它是世界上最绿色的建筑之一 那里的建筑非常美丽
# --------------------------------------------------
# English:            So in my lab, we've been using bats to look at two different types of diseases of the senses.
# Chinese (bert):     所以在我的实验室里, 我们用实验鼠 来研究两种不同的疾病。
# Chinese (base):     在我的实验室,我们一直用蝙蝠来研究 两种不同的感官疾病。
# Chinese (correct):  在我的实验室里,我们一直尝试通过白蝙蝠观察 两种不同类型的感官疾病。
# --------------------------------------------------
# English:            During many years, I made some speeches starting with this saying: "City is not a problem, it's a solution.
# Chinese (bert):     许多年来,我从这个系列演讲做起, 起到了演讲, "工作不是一个问题,而是一个解决方案。
# Chinese (base):     在多年里,我做了一些演讲, 开始说: “意识不是问题,而是一个解决方案。
# Chinese (correct):  很多年以来,我以这个为开头,做了一些演讲 “城市并不是一个难题,而是一种解决方案”
# --------------------------------------------------
# English:            And finally, many different types of questionnaires were used to diagnose PMS, focusing on different symptoms, symptom duration and severity.
# Chinese (bert):     最后,许多不同种类的菌落 被用于不同的昆虫和灵长类动物身上
# Chinese (base):     最后,很多不同的问卷 都习惯了诊断经前综合征, 研究不同的症状, 症状,及时性。
# Chinese (correct):  最后一点,很多不同类型的 用于诊断经前综合征的调查问卷 聚焦于不同的症状、 症状持续的时间和严重性。
# --------------------------------------------------
# English:            And you can't find this guy on Google; you can't find him anywhere.
# Chinese (bert):     你无法在Twitter上找到这个人, 什么地方找不到他。
# Chinese (base):     你在谷歌找不到这个人,你在其他地方找不到他。
# Chinese (correct):  你在谷歌上根本搜不到这个人 哪里都找不到
# --------------------------------------------------
# English:            So, you can find through your Jeep, a camel, and a cart.
# Chinese (bert):     你可以通过你的吉普车发现的骆驼和一个风车
# Chinese (base):     你可以通过杰西法找到答案,一头骆驼,还有一辆推车。
# Chinese (correct):  所以你可以通过你的吉普找到 一只骆驼,一个手推车。
# ...
# Chinese (correct):  去年,我又一次怀孕了。
# --------------------------------------------------
# English:            And now because live demos are always a bad idea, we're going to try a live demo.
# Chinese (bert):     现在,因为养老金总是不好的, 我们要做活儿。
# Chinese (base):     因为现场演示是一个糟糕的主意, 我们打算试试现场演示。
# Chinese (correct):  即便现场演示总是效果不佳, 我们还是要现场展示给大家。
# --------------------------------------------------
# English:            And this brings up mentors.
# Chinese (bert):     这就带来了季候风。
# Chinese (base):     这就带来了导师。
# Chinese (correct):  这就讲到了导师的问题
# --------------------------------------------------
# English:            I think a world where half of our countries and our companies were run by women, would be a better world.
# Chinese (bert):     我认为世界上有一半国家和公司 是由女性主导的, 会是一个更好的世界。
# Chinese (base):     我认为,在我们国家和企业中 有一半以上的国家 是女性,会是一个更好的世界。
# Chinese (correct):  我认为我们世界上 半数国家和半数公司 会由女性所领导,那将会是一个更美好的世界。
# --------------------------------------------------
# English:            There's a reason that few systems have been more waterfall over time than the family.
# Chinese (bert):     少数几个系统 比整个家庭都有更多的瀑布。
# Chinese (base):     原因是,没有几个系统 比起家人有更多的水瀑布。
# Chinese (correct):  这是家庭比其它系统更加倾向于 瀑布管理模型的原因之一。
# --------------------------------------------------
# English:            Tech guru, like this man -- that a German magazine called the philosopher of the 21st century -- they are shaping the way we do things.
# Chinese (bert):     德国杂志—— 一个名叫 21世纪德国杂志的德国杂志—— 他们讨论我们怎么处理事情。
# Chinese (base):     像这位技术专家-- 德国杂志称21世纪哲学家-- 他们正在塑造我们做的事。
# Chinese (correct):  科技领袖们,比如这位先生—— 一本德国杂志称其为21世纪的哲学家 他们正塑造着我们的行事方式
# --------------------------------------------------
# English:            The irony is palpable; technical access has never been greater, cultural access never weaker.
# Chinese (bert):     信息技术革新的革新 革新的革新从未被广泛接受, 从来没有正式的文化交流。
# Chinese (base):     讽刺是可预见的; 技术获取的途径从来都不是更好, 文化的获取。
# Chinese (correct):  这真有讽刺意味 技术正取得史无前例的发展 文化却变得前所未有的贫瘠
# --------------------------------------------------
# English:            Well, yeah, a lot of them.
# Chinese (bert):     是的,很多
# Chinese (base):     是的,很多。
# Chinese (correct):  嗯,有,很大一部分
# --------------------------------------------------
# English:            If they're new books and you can just, you know, butcher them, because you could just buy another one, that's not such a big deal in terms of doing high-quality scanning.
# Chinese (bert):     如果是新的书,你还可以批改他们, 因为你可以去买一个, 这对于做高风险投资来说不是一个大不了的。
# Chinese (base):     如果他们是新的书,你只能, 但是屠宰他们,因为你可以买另一本书, 在高质量的扫描上, 这并不是什么大不了。
# Chinese (correct):  如果是新书,那就不同了,你可以“残害”他们 因为你可以再买一本新的 对于高质量的扫描来说这不算什么大事
# --------------------------------------------------
# English:            Because we thought that what it took to make people happy was to provide them with the most culturally authentic tomato sauce, A.
# Chinese (bert):     因为我们认为导致人们幸福的因素是 给他们提供最富饶的资源。
# Chinese (base):     因为我们认为真正把人们快乐的东西 给他们提供最可口的番茄酱,A。
# Chinese (correct):  因为我们认为要让人们快乐 就要给他们最正宗的番茄酱,这是其一。
# --------------------------------------------------
# English:            Muhammad did not come floating off the mountain as though walking on air.
# Chinese (bert):     米开朗基罗并没有如在空气中散步。
# Chinese (base):     穆罕默德并没有像在陆地上一样从山上漂浮。
# Chinese (correct):  穆罕穆德没有像在空中行走一般 从山上漂浮下来
# --------------------------------------------------
# English:            And we're a non-profit foundation, you can give us the property and take a hell of a tax deduction.
# Chinese (bert):     我们是非营利性组织, 你可以赋予我们的财富,并从中牟利。
# Chinese (base):     我们是非营利性基金会, 你可以给我们这些财富, 得到税收的胜利。
# Chinese (correct):  我们是一个非牟利的基金会,你可以直接把地给我们啊 还能减免一大笔的税金呢
# --------------------------------------------------
# English:            Now, move the base off to the side, and the ring will split up into arcs, OK.
# Chinese (bert):     现在,把基座从左侧移动, 球会分成两半。
# Chinese (base):     现在,把底部移到两边, 这个环形会分成弧形。
# Chinese (correct):  现在,把底座移到另一边, 然后,这个圆环会分裂成一些弧形。
# --------------------------------------------------
# English:            People around the world, in a study of 37 societies, want to be in love with the person that they marry.
# Chinese (bert):     全世界的人,在一项有37个研究中, 想要对他们所爱的人。
# Chinese (base):     全世界的人, 在对37个社会的研究中, 想要和他们结婚的人结婚。
# Chinese (correct):  对37个国家的研究发现,世界各地的人们 只希望与他们所爱的人结婚
# --------------------------------------------------
# English:            But for the past eight years, I've done something completely different.
# Chinese (bert):     但是在过去的八年里, 我做了一件完全不同的事情。
# Chinese (base):     但是在过去的8年里, 我做了一些完全不同的事情。
# Chinese (correct):  承认我的北京。 但在过去的8年, 我做了一些及不寻常的事。
# --------------------------------------------------
# English:            You can see the pictures here. I'll show you a couple.
# Chinese (bert):     你能看到照片,我会给你们看一个镜头
# Chinese (base):     你们能看到这张照片。我会展示一些。
# Chinese (correct):  我给你们看看其中的一些照片。
# --------------------------------------------------
# English:            Ed Cage: Yeah, yeah, yeah!
# Chinese (bert):     爱德华·凯利:是的,对!
# Chinese (base):     男士:是的,是的。
# Chinese (correct):  Ed Cage: 耶,准备好了
# --------------------------------------------------
# English:            But I think it sums up my talk rather well, this, that where there is trust, there is music -- by extension life.
# Chinese (bert):     但我认为它总结了我演讲的主题, 就是音乐本身, 是音乐,生命。
# Chinese (base):     但我认为这就概括出我今天的演讲, 这个,就是信任, 有音乐,延长了人生。
# Chinese (correct):  我想这能说明一切了 有信任 就有音乐-生命的延续
# --------------------------------------------------
# English:            I was a total failure in school, not really headed to graduate high school.
# Chinese (bert):     我上高中的时候完全不是高中毕业的
# Chinese (base):     在学校我表现的完全失败, 并没有从高中毕业。
# Chinese (correct):  在学校,我是一个彻底的失败者,高中都没毕业。
# --------------------------------------------------
# English:            Although, the change in your mind already does something for other beings: they can sense this new quality in yourself, and it helps them already, and gives them an example.
# Chinese (bert):     虽然,你的头脑中对于其它情况来说已经有所改变, 他们能感受到自己内心的新才华, 而且这帮人已经帮助了。
# Chinese (base):     尽管,你大脑中的改变 对于其它生物来说已经有所改变: 他们能感知自己的一种新品质, 而且这已经帮助他们拿来举个例子。
# Chinese (correct):  你头脑中这种想法的改变已经影响到了其他人, 他们能够感觉到你的这一优秀的品质, 而且你的这些品质还可以帮到他们,给他们作了榜样。
# --------------------------------------------------
# English:            They tap into local entrepreneurial talent, and they do incredible marketing.
# Chinese (bert):     它们利用当地资源, 它们拥有不可思议的资源。
# Chinese (base):     他们利用当地企业的才能, 他们做了一个很棒的市场营销活动。
# Chinese (correct):  他们扶持地方企业人才, 他们的市场营销做得天衣无缝。
# --------------------------------------------------
# English:            Profits made, prophets ignored.
# Chinese (bert):     条件反射对称。
# Chinese (base):     先知们使,先知们视而不见。
# Chinese (correct):  先知诞生了,又被无视。
# --------------------------------------------------
# English:            #@nonymous is watching #NSA #GCHQ - we are part of your organizations.
# Chinese (bert):     观察我们自身所处的环境。
# Chinese (base):     #遗憾的是, 看到#GCH #我们是你的组织的一部分。
# Chinese (correct):  “#@匿名者正在监视#国家安全总局 #国家通信总局-我们是你们的人。
# --------------------------------------------------
# English:            But that day I flew low over the islands -- it was a family trip to the Caribbean, and I flew in a small plane low over the islands.
# Chinese (bert):     但是那天晚上我跳过沙发, 那是一家为了去沙滩旅行的家, 我爬上了一个小平面, 在小平面上游过去。
# Chinese (base):     但是那天,我飞低了岛屿, 那是个加勒比海的家旅行, 我飞到一个低空的飞机上。
# Chinese (correct):  但那天我乘飞机飞过一些岛 -- 那是和家人前往加勒比海度假, 我坐小型飞机从低空飞过这些岛。
# --------------------------------------------------
# English:            So this is how it's passed from mother to son.
# Chinese (bert):     所以这是它从母语 传递的方式。
# Chinese (base):     这就是如何通过母亲和儿子实现的。
# Chinese (correct):  这就是它如何从母亲传到儿子的。
# --------------------------------------------------
# English:            Well, the CDC has gone further to say that those children born in the year 2000 could be the first generation in our country's history to die at a younger age than their parents.
# Chinese (bert):     哥伦比亚革命已经进一步表明, 2000年出生的孩子 将会成为我们这个时代第一代 出生时比他们出生时还要少。
# Chinese (base):     CDC更进一步的表明, 那些2000年出生的小孩, 可能是我们国家历史上第一个 因其父母而死去的下一代。
# Chinese (correct):  好吧,疾病防控中心还说了, 那些2000年出生的孩子 可能会成为我们国家历史上首代 寿命短于他们父辈的一代人。
# --------------------------------------------------
# English:            I have no idea whether it makes any difference, but he seemed to make sense, and I wasn't going to test the hypothesis that he'd be wrong.
# Chinese (bert):     我不知道这是否合理, 但是他看上去有道理, 我不打算去测试他犯错误的错误。
# Chinese (base):     我不知道这有什么区别, 但是他似乎有道理, 而我没有测试他的假设是不对的。
# Chinese (correct):  我并不知道这样是否会产生什么不同 但他却使得这个很有道理 我并不想做实验去证明他的假设是错的
# --------------------------------------------------
# English:            So we can't fight the thing with a million-to-one cost, one-to-a-million cost-benefit ratio.
# Chinese (bert):     所以我们不能用100万的一美分一美分一美分一美分一加仑的成本效益分析。
# Chinese (base):     所以我们不能和100万比1的成本来斗争, 100万的成本比率。
# Chinese (correct):  也就是说,我们不能用1百万比1的付出和 1比1百万的收益来解决问题。
# --------------------------------------------------
# English:            So in the Philippines today, parents and students can give real-time feedback on a website, Checkmyschool.org, or using SMS, whether teachers and textbooks are showing up in school, the same problems I witnessed in Uganda and in Bihar.
# Chinese (bert):     所以,在今天的这个研讨会上, 父母和学生可以提供实时反馈 关于一个网站,Chickymy Dickamers.org, 或者使用一些老师,教师和教科书 显示在乌干达和比哈尔邦一样的问题
# Chinese (base):     在今天的菲律宾,父母和学生 可以在网站上 提供实时反馈, Checkmy 学习网站, 还是使用短信服务, 教师和教科书都在学校 出现相同的问题, 就是我在乌干达和比哈尔邦 见到的那些问题。
# Chinese (correct):  在今天的菲律宾,父母与学生 可以在一个名为“Checkmyschool.org”的网站上即时反馈, 或者用短信的方式来反馈情况,比如学校里是否 有足够的老师与课本, 这些我曾经在乌干达和比哈尔亲眼所见的问题。
# --------------------------------------------------
# English:            So think of it this way: think of it as inoculating children against ignorance.
# Chinese (bert):     简单来说, 把它看作是对抗无知的小孩。
# Chinese (base):     所以这样想: 把孩子们灌输给无知。
# Chinese (correct):  因此让我们这样来想: 就好像为愚昧无知 接种疫苗一样。
# --------------------------------------------------
# English:            And then next we have to provide training, capacity building.
# Chinese (bert):     然后,我们得提供稳定的建造。
# Chinese (base):     接下来,我们需要提供培训和建设能力。
# Chinese (correct):  然后,接下来我们必须 提供培训和能力的培养。
# --------------------------------------------------
# English:            Is that 513,284?
# Chinese (bert):     513,284?
# Chinese (base):     那是513,284吗?
# Chinese (correct):  是等于513284吗?
# --------------------------------------------------
# English:            Economists talk about game theory, that every two-person game has a Nash equilibrium.
# Chinese (bert):     经济学谈到博弈论, 一对一的游戏都有纳什效应。
# Chinese (base):     经济学家谈到游戏理论, 每一个两人都是Nash均衡论。
# Chinese (correct):  经济学家讨论博弈论, 说每个双人游戏都存在一个纳什均衡。
# --------------------------------------------------
# English:            She said, "Yes, sir.
# Chinese (bert):     她说,“是的,老师。”
# Chinese (base):     她说:“是的,先生。”
# Chinese (correct):  她说:“是的,先生”
# --------------------------------------------------
# English:            So starting from a three-dimensional ping sound system, a vibrating vest, a click wheel with voice commands, a leg strip, even a shoe that applies pressure to the foot.
# Chinese (bert):     首先从一个三维的声音系统, 一个带声音的转盘,一个转折的转盘, 一个带子的快捷键, 甚至一个声带受到了压力。
# Chinese (base):     所以从一个三维立体声系统开始, 振动背心, 用声音指令,一条腿的轮子, 甚至一只用来控制脚的鞋。
# Chinese (correct):  最初的三维平音响系统, 震动背心, 声控齿轮,腿带, 甚至给脚施压的鞋子。
# --------------------------------------------------
# English:            Several Western companies are now adopting frugal innovation to create affordable products for Western consumers.
# Chinese (bert):     一些制药公司正试图建立起价格创新, 为消费者提供价格服务。
# Chinese (base):     一些西方公司现在已经接受“低成本创新”, 来为西方消费者 创造价格。
# Chinese (correct):  一些西方公司正采用”低成本创新“的思想, 为西方国家消费者设计产品。
# --------------------------------------------------
# English:            Something is up in Pakistan.
# Chinese (bert):     巴基斯坦也有个什么东西
# Chinese (base):     巴基斯坦也有组织。
# Chinese (correct):  在巴基斯坦出事了。”
# --------------------------------------------------
# English:            Give yourself permission to eat as much as you want, and then work on figuring out what makes your body feel good.
# Chinese (bert):     让自己可以吃到你理想里的食物, 然后在研究 了解什么使身体感觉良好。
# Chinese (base):     允许自己去吃尽可能多的食物 然后找出是什么让你的身体感觉良好
# Chinese (correct):  允许自己尽可能的吃 然后找出 吃多少才能让你感觉舒服
# --------------------------------------------------
# English:            And I was just in New York at the launch, and I went to see all these places where they're installed: this is at a Puerto Rican little mom-and-pop store; at a bar in Christopher Street; at a pool hall.
# Chinese (bert):     我在纽约,地铁, 我去了很多地方 他们住的地方。这是 在普尔托市的一家酒吧, 正值圣诞老人的酒吧,
# Chinese (base):     我在起飞的时候在纽约, 去看看他们安装的 所有这些地方: 这是在一个波多黎加的小女孩商店; 在克里斯托弗街的酒吧, 在一座座舱里。
# Chinese (correct):  发行时我刚好在纽约, 我去看它们装设的地方。 这是 Puerto Rican,一家小型杂货店, 克里斯多街的一家酒吧、在撞球场。
# --------------------------------------------------
# English:            And that's huge. And then he turned around and said, "Well, if you back a prize institute that runs a 10 prize, you get 500 to one.
# Chinese (bert):     这是巨大的。然后他转过身说, “好吧,如果你把100块这样的灯泡,它只剩下500块,
# Chinese (base):     这个数字很大。然后他转身说, “如果你创立了10个奖学金院, 你就会拿到500到1个奖。
# Chinese (correct):  那真是非常惊人。接着他转身对我说, 那你资助一个设立了10个奖项的组织的时候,你就能有500:1的杠杆效应了。
# --------------------------------------------------
# English:            If you switch off the cameras tonight, there will be a genocide.
# Chinese (bert):     如果你关掉门,就会有种族灭绝。
# Chinese (base):     如果你晚上关掉相机,那就有种族屠杀。
# Chinese (correct):  如果你们关掉了摄像机 今晚将会发生一场大屠杀
# --------------------------------------------------
# English:            I grew up with the colors of war -- the red colors of fire and blood, the brown tones of earth as it explodes in our faces and the piercing silver of an exploded missile, so bright that nothing can protect your eyes from it.
# Chinese (bert):     我成长于战争的悲剧 - 着火的悲剧 破坏了地球的火焰, 如同在我们的脸上挥发的火焰, 烟消逝的火焰, 没有什么能保护你的眼睛。
# Chinese (base):     我生长在那些颜色的颜色中- 红色的颜色和血, 地球的褐色, 在我们的脸上爆炸荡, 刺穿一股爆炸的银弹, 如此明亮, 肉眼无法保护。
# Chinese (correct):  我在战争的颜色中成长 红色的血与火 棕色的土地 爆炸 就在我面前 还有银色的碎片 导弹爆炸时飞散而来 那么明亮 没有东西可以保护你的眼睛
# --------------------------------------------------
# English:            So we're spending less than a dollar, OK, on lunch.
# Chinese (bert):     所以我们花的还不到1美元,好吧,在公司。
# Chinese (base):     所以我们在午餐时间少于1美元。
# Chinese (correct):  这样看来,我们在午餐上的花费还不足一美元。
# --------------------------------------------------
# English:            And sometimes it comes down to something as simple as, their core wound is their father died without ever saying he's proud of them.
# Chinese (bert):     有的时候, 顺带一提,他们的核心功能, 就是他们的父亲去世, 却从未停止过表达他。
# Chinese (base):     有时事情简单到, 他们的核心伤亡, 从来不说他是自豪。
# Chinese (correct):  有时候这一切可以非常简单地归结为, 他们最核心的创伤来自于他们父亲到死都未说过“他为他们而自豪”。
# --------------------------------------------------
# English:            Yes, yes, yes, women have almost caught up.
# Chinese (bert):     是的,是的,是的,女性们几乎已经答应了。
# Chinese (base):     是的,是的,是的,女性基本上已经赶上了。
# Chinese (correct):  没错 没错 女性几乎赶上了
# --------------------------------------------------
# English:            India didn't want to play the T20 World Cup.
# Chinese (bert):     印度不想要玩T20万的比赛
# Chinese (base):     印度不想要弹T20世界杯
# Chinese (correct):  我们真不想参加T20世界杯
# --------------------------------------------------
# English:            They're also now small enough to sit on a desktop.
# Chinese (bert):     它们也小到能坐在椅子上
# Chinese (base):     它们还小到可以坐在桌面坐的电脑上。
# Chinese (correct):  它们现在已经足够小, 可以放到桌子上面。
# --------------------------------------------------
# English:            So I'll come back to the story of when I was caught in the prison: I was very happy freeing a dozen children from slavery, handing them over to their parents.
# Chinese (bert):     回到那个故事, 当我被抓到笼子里时, 我非常高兴地释放出一组孩子, 将他们交给父母。
# Chinese (base):     所以,我回到 牢狱时的故事: 我非常乐意将十几个孩子 从奴隶主手中解放出来, 把他们交给父母。
# Chinese (correct):  现在回到我被关在监狱里的故事: 那时我解救了十多个被奴役的孩子, 让他们与父母团聚,让我感到无比开心,
# --------------------------------------------------
# English:            Who's got the hero view?
# Chinese (bert):     谁有袋獾?
# Chinese (base):     谁有英雄式的视角?
# Chinese (correct):  谁认为他是英雄?
# --------------------------------------------------
# English:            So, a couple of years ago, we started this project called American Gut, which allows you to claim a place for yourself on this microbial map.
# Chinese (bert):     几年前,我们开展了一个叫做美国居所的项目, 允许你为这个微生物菌落进行定义。
# Chinese (base):     几年前,我们发起了一个叫做美国Gunt的计划, 这个项目可以让你自己 在微生物地图上找到自己的位置。
# Chinese (correct):  几年前, 我们启动了这个叫做 “美国人肠道”的项目, 可以把你添加到微生物分布图上。
# --------------------------------------------------
# English:            You can see that from the orange line and the blue line.
# Chinese (bert):     你可以从上到下,从上到下。
# Chinese (base):     你可以看到这条橙色的线和蓝色的线。
# Chinese (correct):  你可以从橙色和蓝色线中看出来。
# --------------------------------------------------
